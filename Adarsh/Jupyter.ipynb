# %% [markdown]
# # First thursday week of the mentioned month

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
df_t=pd.DataFrame()
df_b=pd.DataFrame()
df_t['T']=pd.bdate_range('2019-01-01', '2019-01-31',freq='W-THU')
df_b['B']=pd.bdate_range('2019-01-01', '2019-01-31',freq='B')
df_b = df_b.set_index(['B'])
start_date=df_t['T'][0]
start_date=pd.to_datetime(start_date).date()
end_date=df_t['T'][1]
end_date=pd.to_datetime(end_date).date()

# %%
df_t=pd.DataFrame()
df_b=pd.DataFrame()
df_t['T']=pd.bdate_range('2019-01-01', '2019-01-31',freq='W-THU')
df_b['B']=pd.bdate_range('2019-01-01', '2019-01-31',freq='B')
df_b = df_b.set_index(['B'])
for i in range(4):
    start_date=df_t['T'][i]
    start_date=pd.to_datetime(start_date).date()
    #print(start_date)
    start_date=df_t['T'][i+1]
    start_date=pd.to_datetime(start_date).date()
    print(end_date)
# Out:
# 2019-01-10
# 2019-01-10
# 2019-01-10
# 2019-01-10

# %%
start_date
# Out:
# datetime.date(2019, 1, 31)

# %%
end_date
# Out:
# datetime.date(2019, 1, 10)

# %%
start_date
# Out:
# datetime.date(2019, 1, 31)

# %%
import os
os.chdir('C:\\Users\\bired\\Desktop\\pics')
df=pd.read_csv('data.csv')
df=df.set_index(['Date'])
df.index = pd.to_datetime(df.index)
round_price=df.loc[start_date]['Close']
x=np.round(round_price,decimals=-2)
print(x)
# Out:
# 27300.0

# %%
close_list = [x]
addsub = [-400,-300,-200,-100,0,100,200,300,400]
a=[[i+j for j in addsub]for i in close_list]
print(a)
# Out:
# [[26900.0, 27000.0, 27100.0, 27200.0, 27300.0, 27400.0, 27500.0, 27600.0, 27700.0]]

# %%
os.chdir('C:\\Users\\bired\\Desktop\\pics')
df=pd.read_csv('nifty3jan.csv')

df=df.drop(["Symbol","Option Type","Settle Price","No. of contracts","Turnover in Lacs","Premium Turnover in Lacs","Open Int","Change in OI","Underlying Value"],axis=1)
df.set_index([pd.DatetimeIndex(df['Expiry']),pd.DatetimeIndex(df['Date']),'Strike Price'],inplace=True)

# %%
df.head()
# Out:
#                                            Date       Expiry  Open  High  Low  \
# Expiry     Date       Strike Price
# 2019-01-10 2019-01-03 23900         03-Jan-2019  10-Jan-2019   0.0   0.0  0.0
#                       29000         03-Jan-2019  10-Jan-2019   2.9   2.9  1.1
#                       24100         03-Jan-2019  10-Jan-2019   0.0   0.0  0.0
#                       24200         03-Jan-2019  10-Jan-2019   0.0   0.0  0.0
#                       24300         03-Jan-2019  10-Jan-2019   0.0   0.0  0.0
#
#                                       Close      LTP
# Expiry     Date       Strike Price
# 2019-01-10 2019-01-03 23900         3287.95  3287.95
#                       29000            1.20     1.10
#                       24100         2124.80     0.00
#                       24200         2051.50     0.00
#                       24300         1978.35     0.00

# %%
start_date1=start_date+pd.offsets.BDay(1)
start_date1=pd.datetime.date(start_date1)

start_date2=start_date+pd.offsets.BDay(2)
start_date2=pd.datetime.date(start_date2)

start_date3=start_date+pd.offsets.BDay(3)
start_date3=pd.datetime.date(start_date3)

start_date4=start_date+pd.offsets.BDay(4)
start_date4=pd.datetime.date(start_date4)

start_date5=start_date+pd.offsets.BDay(5)
start_date5=pd.datetime.date(start_date5)

# %%
start_date1
# Out:
# datetime.date(2019, 2, 1)

# %%
n3=df.loc[end_date].loc[start_date].loc[a[0][0]:a[0][-1]]['Close']
n4=df.loc[end_date].loc[start_date1].loc[a[0][0]:a[0][-1]]['Close']
n7=df.loc[end_date].loc[start_date2].loc[a[0][0]:a[0][-1]]['Close']
n8=df.loc[end_date].loc[start_date3].loc[a[0][0]:a[0][-1]]['Close']
n9=df.loc[end_date].loc[start_date4].loc[a[0][0]:a[0][-1]]['Close']
n10=df.loc[end_date].loc[start_date5].loc[a[0][0]:a[0][-1]]['Close']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.DatetimeEngine._date_check_type()
#
# KeyError: datetime.date(2019, 1, 31)
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\datetimes.py in get_loc(self, key, method, tolerance)
#    1008         try:
# -> 1009             return Index.get_loc(self, key, method, tolerance)
#    1010         except (KeyError, ValueError, TypeError):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.DatetimeEngine._date_check_type()
#
# KeyError: datetime.date(2019, 1, 31)
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# pandas\_libs\index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1548892800000000000
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# KeyError: Timestamp('2019-01-31 00:00:00')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# pandas\_libs\index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1548892800000000000
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\datetimes.py in get_loc(self, key, method, tolerance)
#    1021                     stamp = stamp.tz_localize(self.tz)
# -> 1022                 return Index.get_loc(self, stamp, method, tolerance)
#    1023             except KeyError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.DatetimeEngine.get_loc()
#
# KeyError: Timestamp('2019-01-31 00:00:00')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-3c893cb74710> in <module>
# ----> 1 n3=df.loc[end_date].loc[start_date].loc[a[0][0]:a[0][-1]]['Close']
#       2 n4=df.loc[end_date].loc[start_date1].loc[a[0][0]:a[0][-1]]['Close']
#       3 n7=df.loc[end_date].loc[start_date2].loc[a[0][0]:a[0][-1]]['Close']
#       4 n8=df.loc[end_date].loc[start_date3].loc[a[0][0]:a[0][-1]]['Close']
#       5 n9=df.loc[end_date].loc[start_date4].loc[a[0][0]:a[0][-1]]['Close']
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1911         # fall thru to straight lookup
#    1912         self._validate_key(key, axis)
# -> 1913         return self._get_label(key, axis=axis)
#    1914
#    1915
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#     139             raise IndexingError('no slices here, handle elsewhere')
#     140
# --> 141         return self.obj._xs(label, axis=axis)
#     142
#     143     def _get_loc(self, key, axis=None):
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3581         if isinstance(index, MultiIndex):
#    3582             loc, new_index = self.index.get_loc_level(key,
# -> 3583                                                       drop_level=drop_level)
#    3584         else:
#    3585             loc = self.index.get_loc(key)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\multi.py in get_loc_level(self, key, level, drop_level)
#    2569                 return indexer, maybe_droplevels(indexer, ilevels, drop_level)
#    2570         else:
# -> 2571             indexer = self._get_level_indexer(key, level=level)
#    2572             return indexer, maybe_droplevels(indexer, [level], drop_level)
#    2573
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\multi.py in _get_level_indexer(self, key, level, indexer)
#    2650         else:
#    2651
# -> 2652             code = level_index.get_loc(key)
#    2653
#    2654             if level > 0 or self.lexsort_depth == 0:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\datetimes.py in get_loc(self, key, method, tolerance)
#    1022                 return Index.get_loc(self, stamp, method, tolerance)
#    1023             except KeyError:
# -> 1024                 raise KeyError(key)
#    1025             except ValueError as e:
#    1026                 # list-like tolerance size must match target index size
#
# KeyError: datetime.date(2019, 1, 31)

# %%
n3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-3275fb33a299> in <module>
# ----> 1 n3
#
# NameError: name 'n3' is not defined

# %%
n4

# %%
from functools import reduce
dfs = [n3,n4,n7,n8,n9,n10]
df = reduce(lambda a,b: pd.merge(a,b,on='Strike Price'), dfs)
df.columns = [start_date,start_date1,start_date2,start_date3,start_date4,start_date5]
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-4ef569980642> in <module>
#       1 from functools import reduce
# ----> 2 dfs = [n3,n4,n7,n8,n9,n10]
#       3 df = reduce(lambda a,b: pd.merge(a,b,on='Strike Price'), dfs)
#       4 df.columns = [start_date,start_date1,start_date2,start_date3,start_date4,start_date5]
#       5 df
#
# NameError: name 'n3' is not defined

# %%
## import matplotlib library to plot the diagramatic ways
import matplotlib.pyplot as plt
# %matplotlib inline

## creating a x and y axis values from the final dataframe and ploting the graph through it
x=['3-jan','4-jan','7-jan','8-jan','9-jan','10-jan']
y=[231.6,342.30,344.15,501.15,650.75,521.35]
plt.plot(x,y,'ro--')
plt.xlabel('Date')
plt.ylabel('strike price_27000')
# Out:
# Text(0, 0.5, 'strike price_27000')

# %% [markdown]
# # 1 week for PE

# %%
os.chdir('C:\\Users\\bired\\Desktop\\pics')
df1=pd.read_csv('nifty3.PE.csv')

df1=df1.drop(["Symbol","Option Type","Settle Price","No. of contracts","Turnover in Lacs","Premium Turnover in Lacs","Open Int","Change in OI","Underlying Value"],axis=1)
df1.set_index([pd.DatetimeIndex(df1['Expiry']),pd.DatetimeIndex(df1['Date']),'Strike Price'],inplace=True)

# %%
df1
# Out:
#               2019-01-03  2019-01-04  2019-01-07  2019-01-08  2019-01-09  \
# Strike Price
# 26600              84.75       26.15       12.45        4.90        2.05
# 26700             110.95       37.35       18.60        6.60        2.25
# 26800             141.10       53.65       28.00        9.55        2.80
# 26900             180.30       74.00       40.45       14.15        3.30
# 27000             223.90      101.05       57.55       21.35        4.35
# 27100             277.75      134.60       79.95       31.25        5.75
# 27200             336.30      174.35      113.80       45.90        7.85
# 27300             402.35      219.70      156.35       68.30       12.05
# 27400             471.90      274.55      209.40       99.20       21.70
#
#               2019-01-10
# Strike Price
# 26600               0.05
# 26700               0.05
# 26800               0.05
# 26900               0.05
# 27000               0.05
# 27100               0.10
# 27200               0.05
# 27300               0.05
# 27400               0.15

# %%
df1.head()
# Out:
#                                            Date       Expiry    Open    High  \
# Expiry     Date       Strike Price
# 2019-01-10 2019-01-03 23900         03-Jan-2019  10-Jan-2019     0.0     0.0
#                       29000         03-Jan-2019  10-Jan-2019  1760.0  1941.1
#                       24100         03-Jan-2019  10-Jan-2019     0.0     0.0
#                       24200         03-Jan-2019  10-Jan-2019     0.0     0.0
#                       24300         03-Jan-2019  10-Jan-2019     0.0     0.0
#
#                                        Low    Close     LTP
# Expiry     Date       Strike Price
# 2019-01-10 2019-01-03 23900            0.0   221.15     0.0
#                       29000         1760.0  1941.10  1941.1
#                       24100            0.0   314.35     0.0
#                       24200            0.0   339.75     0.0
#                       24300            0.0   365.35     0.0

# %%
df_t=pd.DataFrame()
df_b=pd.DataFrame()
df_t['T']=pd.bdate_range('2019-01-01', '2019-01-31',freq='W-THU')
df_b['B']=pd.bdate_range('2019-01-01', '2019-01-31',freq='B')
df_b = df_b.set_index(['B'])
start_date=df_t['T'][0]
start_date=pd.to_datetime(start_date).date()
end_date=df_t['T'][1]
end_date=pd.to_datetime(end_date).date()

# %%
import os
os.chdir('C:\\Users\\bired\\Desktop\\pics')
df=pd.read_csv('data.csv')
df=df.set_index(['Date'])
df.index = pd.to_datetime(df.index)
round_price=df.loc[start_date]['Close']
x=np.round(round_price,decimals=-2)
print(x)
# Out:
# 27000.0

# %%
close_list = [x]
addsub = [-400,-300,-200,-100,0,100,200,300,400]
a=[[i+j for j in addsub]for i in close_list]
print(a)
# Out:
# [[26600.0, 26700.0, 26800.0, 26900.0, 27000.0, 27100.0, 27200.0, 27300.0, 27400.0]]

# %%
start_date1=start_date+pd.offsets.BDay(1)
start_date1=pd.datetime.date(start_date1)

start_date2=start_date+pd.offsets.BDay(2)
start_date2=pd.datetime.date(start_date2)

start_date3=start_date+pd.offsets.BDay(3)
start_date3=pd.datetime.date(start_date3)

start_date4=start_date+pd.offsets.BDay(4)
start_date4=pd.datetime.date(start_date4)

start_date5=start_date+pd.offsets.BDay(5)
start_date5=pd.datetime.date(start_date5)

# %%
n3=df1.loc[end_date].loc[start_date].loc[a[0][0]:a[0][-1]]['Close']
n4=df1.loc[end_date].loc[start_date1].loc[a[0][0]:a[0][-1]]['Close']
n7=df1.loc[end_date].loc[start_date2].loc[a[0][0]:a[0][-1]]['Close']
n8=df1.loc[end_date].loc[start_date3].loc[a[0][0]:a[0][-1]]['Close']
n9=df1.loc[end_date].loc[start_date4].loc[a[0][0]:a[0][-1]]['Close']
n10=df1.loc[end_date].loc[start_date5].loc[a[0][0]:a[0][-1]]['Close']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: datetime.date(2019, 1, 10)
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-105-81b9d7dfc539> in <module>
# ----> 1 n3=df1.loc[end_date].loc[start_date].loc[a[0][0]:a[0][-1]]['Close']
#       2 n4=df1.loc[end_date].loc[start_date1].loc[a[0][0]:a[0][-1]]['Close']
#       3 n7=df1.loc[end_date].loc[start_date2].loc[a[0][0]:a[0][-1]]['Close']
#       4 n8=df1.loc[end_date].loc[start_date3].loc[a[0][0]:a[0][-1]]['Close']
#       5 n9=df1.loc[end_date].loc[start_date4].loc[a[0][0]:a[0][-1]]['Close']
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1911         # fall thru to straight lookup
#    1912         self._validate_key(key, axis)
# -> 1913         return self._get_label(key, axis=axis)
#    1914
#    1915
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#     139             raise IndexingError('no slices here, handle elsewhere')
#     140
# --> 141         return self.obj._xs(label, axis=axis)
#     142
#     143     def _get_loc(self, key, axis=None):
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3583                                                       drop_level=drop_level)
#    3584         else:
# -> 3585             loc = self.index.get_loc(key)
#    3586
#    3587             if isinstance(loc, np.ndarray):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: datetime.date(2019, 1, 10)

# %%
from functools import reduce
dfs = [n3,n4,n7,n8,n9,n10]
df1 = reduce(lambda a,b: pd.merge(a,b,on='Strike Price'), dfs)
df1.columns = [start_date,start_date1,start_date2,start_date3,start_date4,start_date5]
df1
# Out:
#               2019-01-03  2019-01-04  2019-01-07  2019-01-08  2019-01-09  \
# Strike Price
# 26600             476.20      665.05      696.20      872.90     1044.45
# 26700             403.70      566.85      594.60      776.00      935.85
# 26800             338.35      491.95      507.05      677.60      845.25
# 26900             282.45      414.95      421.00      590.80      747.25
# 27000             231.65      342.30      344.15      501.15      650.75
# 27100             187.30      280.00      275.75      404.45      553.55
# 27200             148.20      221.75      214.40      317.95      458.05
# 27300             114.50      171.70      161.95      244.45      360.75
# 27400              86.75      128.25      119.50      181.60      275.05
#
#               2019-01-10
# Strike Price
# 26600             918.45
# 26700             831.95
# 26800             725.15
# 26900             630.55
# 27000             521.35
# 27100             413.35
# 27200             318.70
# 27300             222.40
# 27400             124.15

# %% [markdown]
# # extracting CE&PE from all.csv

# %%
df=pd.read_csv("all.csv")

# %%
df.head()
# Out:
#       Symbol         Date       Expiry Option Type Strike Price Open High Low  \
# 0  BANKNIFTY  02-May-2019  09-May-2019          CE        26200    0    0   0
# 1  BANKNIFTY  02-May-2019  09-May-2019          CE        32100    0    0   0
# 2  BANKNIFTY  02-May-2019  09-May-2019          CE        26400    0    0   0
# 3  BANKNIFTY  02-May-2019  09-May-2019          CE        26500    0    0   0
# 4  BANKNIFTY  02-May-2019  09-May-2019          CE        26600    0    0   0
#
#      Close LTP Settle Price No. of contracts Turnover in Lacs  \
# 0   2009.4   0      3542.85                0                0
# 1     83.8   0          0.4                0                0
# 2   1841.3   0      3343.15                0                0
# 3  1759.45   0      3243.25                0                0
# 4   1679.1   0       3143.4                0                0
#
#   Premium Turnover in Lacs Open Int Change in OI Underlying Value
# 0                        0        0            0                -
# 1                        0        0            0                -
# 2                        0        0            0                -
# 3                        0        0            0                -
# 4                        0        0            0                -

# %%
df.shape
# Out:
# (16412, 17)

# %%
df= df[df['Option Type'] == 'CE']

# %%
df.shape
# Out:
# (8181, 17)

# %%
df.head()
# Out:
#       Symbol         Date       Expiry Option Type Strike Price Open High Low  \
# 0  BANKNIFTY  02-May-2019  09-May-2019          CE        26200    0    0   0
# 1  BANKNIFTY  02-May-2019  09-May-2019          CE        32100    0    0   0
# 2  BANKNIFTY  02-May-2019  09-May-2019          CE        26400    0    0   0
# 3  BANKNIFTY  02-May-2019  09-May-2019          CE        26500    0    0   0
# 4  BANKNIFTY  02-May-2019  09-May-2019          CE        26600    0    0   0
#
#      Close LTP Settle Price No. of contracts Turnover in Lacs  \
# 0   2009.4   0      3542.85                0                0
# 1     83.8   0          0.4                0                0
# 2   1841.3   0      3343.15                0                0
# 3  1759.45   0      3243.25                0                0
# 4   1679.1   0       3143.4                0                0
#
#   Premium Turnover in Lacs Open Int Change in OI Underlying Value
# 0                        0        0            0                -
# 1                        0        0            0                -
# 2                        0        0            0                -
# 3                        0        0            0                -
# 4                        0        0            0                -

# %%
df=df.drop(["Symbol","Option Type","Settle Price","No. of contracts","Turnover in Lacs","Premium Turnover in Lacs","Open Int","Change in OI","Underlying Value"],axis=1)
df.set_index([pd.DatetimeIndex(df['Expiry']),pd.DatetimeIndex(df['Date']),'Strike Price'],inplace=True)

# %%
df.shape
# Out:
# (8181, 7)

# %%
df[0:10]
# Out:
#                                            Date       Expiry  Open     High  \
# Expiry     Date       Strike Price
# 2019-05-09 2019-05-02 26200         02-May-2019  09-May-2019     0        0
#                       32100         02-May-2019  09-May-2019     0        0
#                       26400         02-May-2019  09-May-2019     0        0
#                       26500         02-May-2019  09-May-2019     0        0
#                       26600         02-May-2019  09-May-2019     0        0
#                       26700         02-May-2019  09-May-2019  3100     3100
#                       26800         02-May-2019  09-May-2019     0        0
#                       26900         02-May-2019  09-May-2019     0        0
#                       27000         02-May-2019  09-May-2019  2773  2874.25
#                       27100         02-May-2019  09-May-2019     0        0
#
#                                        Low    Close     LTP
# Expiry     Date       Strike Price
# 2019-05-09 2019-05-02 26200              0   2009.4       0
#                       32100              0     83.8       0
#                       26400              0   1841.3       0
#                       26500              0  1759.45       0
#                       26600              0   1679.1       0
#                       26700         3077.8   3077.8  3077.8
#                       26800              0   1523.4       0
#                       26900              0   1448.2       0
#                       27000         2694.2   2694.2  2694.2
#                       27100              0   1303.1       0

# %%
df_t=pd.DataFrame()
df_b=pd.DataFrame()
df_t['T']=pd.bdate_range('2019-01-01', '2019-01-31',freq='W-THU')
df_b['B']=pd.bdate_range('2019-01-01', '2019-01-31',freq='B')
df_b = df_b.set_index(['B'])
for i in range(4):
    start_date=df_t['T'][i]
    start_date=pd.to_datetime(start_date).date()
    print(start_date)
    start_date=df_t['T'][i+1]
    start_date=pd.to_datetime(start_date).date()
    #print(end_date)
# Out:
# 2019-01-03
# 2019-01-10
# 2019-01-17
# 2019-01-24

# %%
import os
os.chdir('C:\\Users\\bired\\Desktop\\pics')
df=pd.read_csv('data.csv')
df=df.set_index(['Date'])
df.index = pd.to_datetime(df.index)
round_price=df.loc[start_date]['Close']
x=np.round(round_price,decimals=-2)
print(x)
# Out:
# 27300.0

# %%
close_list = [x]
addsub = [-400,-300,-200,-100,0,100,200,300,400]
a=[[i+j for j in addsub]for i in close_list]
print(a)
# Out:
# [[26900.0, 27000.0, 27100.0, 27200.0, 27300.0, 27400.0, 27500.0, 27600.0, 27700.0]]

# %%
start_date1=start_date+pd.offsets.BDay(1)
start_date1=pd.datetime.date(start_date1)

start_date2=start_date+pd.offsets.BDay(2)
start_date2=pd.datetime.date(start_date2)

start_date3=start_date+pd.offsets.BDay(3)
start_date3=pd.datetime.date(start_date3)

start_date4=start_date+pd.offsets.BDay(4)
start_date4=pd.datetime.date(start_date4)

start_date5=start_date+pd.offsets.BDay(5)
start_date5=pd.datetime.date(start_date5)

# %%
n3=df.loc[end_date].loc[start_date].loc[a[0][0]:a[0][-1]]['Close']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: datetime.date(2019, 1, 31)
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-120-5f966d0ceed6> in <module>
# ----> 1 n3=df.loc[end_date].loc[start_date].loc[a[0][0]:a[0][-1]]['Close']
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1911         # fall thru to straight lookup
#    1912         self._validate_key(key, axis)
# -> 1913         return self._get_label(key, axis=axis)
#    1914
#    1915
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#     135             # but will fail when the index is not present
#     136             # see GH5667
# --> 137             return self.obj._xs(label, axis=axis)
#     138         elif isinstance(label, tuple) and isinstance(label[axis], slice):
#     139             raise IndexingError('no slices here, handle elsewhere')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3583                                                       drop_level=drop_level)
#    3584         else:
# -> 3585             loc = self.index.get_loc(key)
#    3586
#    3587             if isinstance(loc, np.ndarray):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: datetime.date(2019, 1, 31)

# %%
n3=df.loc[end_date].loc[start_date].loc[a[0][0]:a[0][-1]]['Close']
n4=df.loc[end_date].loc[start_date1].loc[a[0][0]:a[0][-1]]['Close']
n7=df.loc[end_date].loc[start_date2].loc[a[0][0]:a[0][-1]]['Close']
n8=df.loc[end_date].loc[start_date3].loc[a[0][0]:a[0][-1]]['Close']
n9=df.loc[end_date].loc[start_date4].loc[a[0][0]:a[0][-1]]['Close']
n10=df.loc[end_date].loc[start_date5].loc[a[0][0]:a[0][-1]]['Close']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: datetime.date(2019, 1, 31)
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-3c893cb74710> in <module>
# ----> 1 n3=df.loc[end_date].loc[start_date].loc[a[0][0]:a[0][-1]]['Close']
#       2 n4=df.loc[end_date].loc[start_date1].loc[a[0][0]:a[0][-1]]['Close']
#       3 n7=df.loc[end_date].loc[start_date2].loc[a[0][0]:a[0][-1]]['Close']
#       4 n8=df.loc[end_date].loc[start_date3].loc[a[0][0]:a[0][-1]]['Close']
#       5 n9=df.loc[end_date].loc[start_date4].loc[a[0][0]:a[0][-1]]['Close']
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1911         # fall thru to straight lookup
#    1912         self._validate_key(key, axis)
# -> 1913         return self._get_label(key, axis=axis)
#    1914
#    1915
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#     135             # but will fail when the index is not present
#     136             # see GH5667
# --> 137             return self.obj._xs(label, axis=axis)
#     138         elif isinstance(label, tuple) and isinstance(label[axis], slice):
#     139             raise IndexingError('no slices here, handle elsewhere')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3583                                                       drop_level=drop_level)
#    3584         else:
# -> 3585             loc = self.index.get_loc(key)
#    3586
#    3587             if isinstance(loc, np.ndarray):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: datetime.date(2019, 1, 31)

# %%
from functools import reduce
dfs = [n3,n4,n7,n8,n9,n10]
df = reduce(lambda a,b: pd.merge(a,b,on='Strike Price'), dfs)
df.columns = [start_date,start_date1,start_date2,start_date3,start_date4,start_date5]
df1
# Out:
#             Date      Open      High       Low     Close  Shares Traded  \
# 0    01-Jan-2019  27231.40  27430.55  27019.05  27392.40      116379065
# 1    02-Jan-2019  27297.00  27397.55  27077.60  27174.70      176599164
# 2    03-Jan-2019  27181.60  27206.20  26923.75  26959.85      151201387
# 3    04-Jan-2019  26999.70  27274.50  26926.10  27195.00      189451222
# 4    07-Jan-2019  27378.65  27477.80  27279.55  27304.55      161026470
# 5    08-Jan-2019  27301.90  27542.40  27161.95  27509.50      150550286
# 6    09-Jan-2019  27651.25  27754.45  27409.50  27720.40      199818392
# 7    10-Jan-2019  27713.55  27713.55  27488.20  27528.55      139266179
# 8    11-Jan-2019  27602.80  27612.45  27382.45  27453.90      116552104
# 9    14-Jan-2019  27389.20  27389.80  27182.20  27248.25      212863498
# 10   15-Jan-2019  27317.55  27447.55  27317.10  27400.75      161396521
# 11   16-Jan-2019  27405.65  27554.75  27403.05  27483.70      183688179
# 12   17-Jan-2019  27568.60  27611.55  27335.15  27528.75      212321274
# 13   18-Jan-2019  27550.05  27576.45  27410.65  27456.70      129067258
# 14   21-Jan-2019  27514.55  27622.20  27388.50  27533.60      128881764
# 15   22-Jan-2019  27526.55  27533.35  27385.40  27482.25      138997867
# 16   23-Jan-2019  27493.10  27564.70  27189.60  27250.75      126935738
# 17   24-Jan-2019  27273.50  27342.35  27142.80  27266.40      210279603
# 18   25-Jan-2019  27261.45  27433.55  27045.20  27115.30      284535180
# 19   28-Jan-2019  27041.45  27134.20  26587.95  26653.05      181836992
# 20   29-Jan-2019  26616.25  26743.85  26441.55  26573.40      194369347
# 21   30-Jan-2019  26789.75  26916.25  26693.70  26825.50      249270714
# 22   31-Jan-2019  26969.15  27325.05  26891.05  27295.45      306292995
# 23   01-Feb-2019  27334.55  27533.05  26930.45  27085.95      238794913
# 24   04-Feb-2019  26974.00  27243.80  26825.55  27186.60      173078574
# 25   05-Feb-2019  27226.05  27348.25  27153.20  27271.70      189860429
# 26   06-Feb-2019  27326.20  27428.65  27294.10  27402.35      164747849
# 27   07-Feb-2019  27424.10  27589.75  27322.95  27387.15      156626117
# 28   08-Feb-2019  27302.65  27482.10  27221.25  27294.40      142258447
# 29   11-Feb-2019  27240.50  27305.90  27151.55  27227.80      117311228
# ..           ...       ...       ...       ...       ...            ...
# 87   10-May-2019  28927.60  29202.85  28900.10  29040.50      223514610
# 88   13-May-2019  29026.65  29049.05  28621.10  28659.95      253600119
# 89   14-May-2019  28718.75  29058.30  28582.60  28829.20      256593306
# 90   15-May-2019  28925.45  28983.15  28555.15  28616.45      218778407
# 91   16-May-2019  28625.90  28947.60  28525.45  28855.30      189440058
# 92   17-May-2019  28881.40  29559.45  28856.00  29450.15      257111157
# 93   20-May-2019  30230.40  30827.85  30111.20  30759.70      321102950
# 94   21-May-2019  30862.10  30926.70  30265.10  30308.40      216423886
# 95   22-May-2019  30410.65  30675.10  30268.60  30526.80      224425509
# 96   23-May-2019  30962.80  31705.00  30292.35  30409.10      494083740
# 97   24-May-2019  30685.50  31275.40  30564.40  31212.55      282765890
# 98   27-May-2019  31234.90  31700.75  31142.50  31647.65      239161158
# 99   28-May-2019  31711.30  31712.40  31328.60  31597.90      297603975
# 100  29-May-2019  31459.25  31546.75  31257.90  31295.55      205161779
# 101  30-May-2019  31256.85  31619.25  31236.10  31537.10      202699071
# 102  31-May-2019  31678.90  31783.60  30623.05  31375.40      230847583
# 103  03-Jun-2019  31406.05  31674.60  31284.70  31653.65      160090476
# 104  04-Jun-2019  31532.90  31752.70  31512.95  31589.05      172424592
# 105  06-Jun-2019  31523.95  31541.50  30800.80  30857.40      283140588
# 106  07-Jun-2019  30943.15  31139.60  30627.05  31066.55      215267224
# 107  10-Jun-2019  31259.20  31367.40  30861.30  31034.00      208614002
# 108  11-Jun-2019  31172.25  31399.35  30973.35  31265.45      188115329
# 109  12-Jun-2019  31219.30  31222.30  30911.45  30965.70      143703508
# 110  13-Jun-2019  30876.75  31036.90  30638.25  30976.10      341891022
# 111  14-Jun-2019  30983.45  31032.65  30508.95  30614.35      255356460
# 112  17-Jun-2019  30652.00  30684.05  30249.40  30273.25      184466679
# 113  18-Jun-2019  30299.45  30550.65  30222.85  30351.00      241865592
# 114  19-Jun-2019  30526.50  30699.15  30242.00  30362.10      252889076
# 115  20-Jun-2019  30390.20  30824.55  30220.70  30781.10      293131675
# 116  21-Jun-2019  30804.95  30804.95  30541.50  30628.35      238841807
#
#      Turnover (Rs. Cr)
# 0              3497.39
# 1              4422.44
# 2              4032.83
# 3              4440.79
# 4              4112.84
# 5              4359.43
# 6              6148.74
# 7              4308.94
# 8              3510.63
# 9              4859.32
# 10             3884.40
# 11             4155.93
# 12             4941.09
# 13             3343.81
# 14             4626.77
# 15             4661.51
# 16             3525.23
# 17             5373.42
# 18             7269.49
# 19             5404.63
# 20             5235.15
# 21             8955.81
# 22             9985.48
# 23             6813.15
# 24             4342.07
# 25             4160.27
# 26             3816.51
# 27             3637.06
# 28             3838.29
# 29             3186.38
# ..                 ...
# 87             6070.63
# 88             5356.35
# 89             6110.47
# 90             5126.91
# 91             4501.11
# 92             6489.10
# 93             9217.22
# 94             5968.41
# 95             7602.50
# 96            14547.69
# 97             7946.04
# 98             6533.11
# 99             6998.27
# 100            5053.90
# 101            5776.18
# 102            7113.52
# 103            4443.90
# 104            4627.37
# 105            7895.98
# 106            5593.78
# 107            4870.64
# 108            4371.70
# 109            3787.08
# 110            7587.55
# 111            6366.06
# 112            5401.37
# 113            6147.16
# 114            5825.47
# 115            6983.33
# 116            6101.47
#
# [117 rows x 7 columns]
