# %%
import numpy as np
import pandas as pd
import os
os.chdir("C:\\Users\\bired\\Desktop\\pics")

### changing a current directory to read the csv file and read csv file 
df=pd.read_csv('nifty3jan.csv')

## droping unwanted columns and set the [expiry,date,strikeprice] as index
df=df.drop(["Symbol","Option Type","Settle Price","No. of contracts","Turnover in Lacs","Premium Turnover in Lacs","Open Int","Change in OI","Underlying Value"],axis=1)
df.set_index(['Expiry','Date','Strike Price'],inplace=True)

# %%
## from this dataframe we extract the close value of 03-jan-2019
os.chdir('C:\\Users\\bired\\Desktop\\pics')
df1=pd.read_csv('Data.csv')
df1=df1.set_index('Date')
x=df1.loc['03-Jan-2019']['Close']
x=np.round(x,decimals=-2)

df2=pd.date_range(start='1/1/2019',end='1/31/2019',freq='W-THU')
df3=pd.date_range(start='1/1/2019',end='1/31/2019',freq='B')
df4=pd.date_range(start='1/1/2019',end='1/31/2019',freq='D')
for i in df2:
    print(i)
for j in df3:
    if i == j :
    Thursday.weekday() +1
# Out:
#   File "<ipython-input-15-29994ed40aa5>", line 15
#     Thursday.weekday() +1
#            ^
# IndentationError: expected an indented block

# %%
# Out:
# 2019-01-03 00:00:00
# 2019-01-03 00:00:00
# 2019-01-10 00:00:00
# 2019-01-10 00:00:00
# 2019-01-17 00:00:00
# 2019-01-17 00:00:00
# 2019-01-24 00:00:00
# 2019-01-24 00:00:00
# 2019-01-31 00:00:00
# 2019-01-31 00:00:00

# %%
dRan3 = pd.date_range(start ='01-03-2017',  
            end ='1-1-2018', periods = 13)

# %%
dRan3
# Out:
# DatetimeIndex(['2017-01-03 00:00:00', '2017-02-02 06:00:00',
#                '2017-03-04 12:00:00', '2017-04-03 18:00:00',
#                '2017-05-04 00:00:00', '2017-06-03 06:00:00',
#                '2017-07-03 12:00:00', '2017-08-02 18:00:00',
#                '2017-09-02 00:00:00', '2017-10-02 06:00:00',
#                '2017-11-01 12:00:00', '2017-12-01 18:00:00',
#                '2018-01-01 00:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=['3-jan','4-jan','7-jan','8-jan','9-jan','10-jan']
y=[223.90,101.05,57.55,21.35,4.35,0.05]
y1=[231.6,342.30,344.15,501.15,650.75,521.35]
plt.plot(x,y,'go--')
plt.plot(x,y1,'ro--')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=['3-jan','4-jan','7-jan','8-jan','9-jan','10-jan']
y=[223.90,101.05,57.55,21.35,4.35,0.05]
y1=[231.6,342.30,344.15,501.15,650.75,521.35]
plt.figure()
plt.subplot(1,2,1)
plt.plot(x,y,'ro--')
plt.xlabel=("Date")
plt.ylabel('strike price_27000')
plt.title("CE")
#plotting PE
plt.figure()
plt.subplot(1,2,2)
plt.plot(x,y1,'go--')
plt.xlabel=("Date")
plt.ylabel('strike price_27000')
plt.title("PE")
# Out:
# Text(0.5, 1.0, 'PE')

# %%
plt.subplot(1, 2, 1)
plt.plot(x, y, 'b--')
plt.title("CE")
plt.ylabel('strike price_27000')


plt.subplot(1, 2, 2)
plt.plot(x, y1, 'r--')
plt.title('PE')
plt.xlabel('date')
plt.ylabel('strike price_27000')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-efdd933055ef> in <module>
#       8 plt.plot(x, y1, 'r--')
#       9 plt.title('PE')
# ---> 10 plt.xlabel('date')
#      11 plt.ylabel('strike price_27000')
#      12 plt.show()
#
# TypeError: 'str' object is not callable

# %%
#merging of both CE &PE
import numpy as np
import pandas as pd
import os

### changing a current directory to read the csv file and read csv file 
os.chdir('C:\\Users\\bired\\Desktop\\pics')
df=pd.read_csv('nifty3jan.csv')

## droping unwanted columns and set the [expiry,date,strikeprice] as index
df=df.drop(["Symbol","Option Type","Settle Price","No. of contracts","Turnover in Lacs","Premium Turnover in Lacs","Open Int","Change in OI","Underlying Value"],axis=1)
df.set_index(['Expiry','Date','Strike Price'],inplace=True)

# %%
df.head()
# Out:
#                                       Open  High  Low    Close      LTP
# Expiry      Date        Strike Price
# 10-Jan-2019 03-Jan-2019 23900          0.0   0.0  0.0  3287.95  3287.95
#                         29000          2.9   2.9  1.1     1.20     1.10
#                         24100          0.0   0.0  0.0  2124.80     0.00
#                         24200          0.0   0.0  0.0  2051.50     0.00
#                         24300          0.0   0.0  0.0  1978.35     0.00

# %%
import pandas as pd
import numpy as np
import os
df_t=pd.DataFrame()
df_b=pd.DataFrame()
df_t['T']=pd.bdate_range('2019-01-01', '2019-01-31',freq='W-THU')
df_b['B']=pd.bdate_range('2019-01-01', '2019-01-31',freq='B')
df_b = df_b.set_index(['B'])
start_date=df_t['T'][0]
start_date=pd.to_datetime(start_date).date()
print(start_date)
end_date=df_t['T'][1]
end_date=pd.to_datetime(end_date).date()
end_date
# Out:
# 2019-01-03
# datetime.date(2019, 1, 10)

# %%
start_date
# Out:
# datetime.date(2019, 1, 3)

# %%
import os
os.chdir('C:\\Users\\bired\\Desktop\\pics')
df=pd.read_csv('data.csv')
df=df.set_index(['Date'])
df.index = pd.to_datetime(df.index)
round_price=df.loc[start_date]['Close']
x=np.round(round_price,decimals=-2)

# %%
close_list = [x]
addsub = [-400,-300,-200,-100,0,100,200,300,400]
a=[[i+j for j in addsub]for i in close_list]

# %%
## extracting the values of close from 3-jan to 10-jan from df dataframe
n3=df.loc['10-Jan-2019'].loc['03-Jan-2019'].loc[26600:27400]['Close']
n4=df.loc['10-Jan-2019'].loc['04-Jan-2019'].loc[26600:27400]['Close']
n7=df.loc['10-Jan-2019'].loc['07-Jan-2019'].loc[26600:27400]['Close']
n8=df.loc['10-Jan-2019'].loc['08-Jan-2019'].loc[26600:27400]['Close']
n9=df.loc['10-Jan-2019'].loc['09-Jan-2019'].loc[26600:27400]['Close']
n10=df.loc['10-Jan-2019'].loc['10-Jan-2019'].loc[26600:27400]['Close']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '03-Jan-2019'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-dd5a6a333189> in <module>
#       1 ## extracting the values of close from 3-jan to 10-jan from df dataframe
# ----> 2 n3=df.loc['10-Jan-2019'].loc['03-Jan-2019'].loc[26600:27400]['Close']
#       3 n4=df.loc['10-Jan-2019'].loc['04-Jan-2019'].loc[26600:27400]['Close']
#       4 n7=df.loc['10-Jan-2019'].loc['07-Jan-2019'].loc[26600:27400]['Close']
#       5 n8=df.loc['10-Jan-2019'].loc['08-Jan-2019'].loc[26600:27400]['Close']
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1911         # fall thru to straight lookup
#    1912         self._validate_key(key, axis)
# -> 1913         return self._get_label(key, axis=axis)
#    1914
#    1915
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#     135             # but will fail when the index is not present
#     136             # see GH5667
# --> 137             return self.obj._xs(label, axis=axis)
#     138         elif isinstance(label, tuple) and isinstance(label[axis], slice):
#     139             raise IndexingError('no slices here, handle elsewhere')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3583                                                       drop_level=drop_level)
#    3584         else:
# -> 3585             loc = self.index.get_loc(key)
#    3586
#    3587             if isinstance(loc, np.ndarray):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '03-Jan-2019'

# %%
m1=pd.merge(n3,n4,how='left',on=['Strike Price'])
m1=m1.rename(columns={'Close_x':start_date,'Close_y':'04-Jan-2019'})

m2=pd.merge(m1,n4,how='left',on=['Strike Price'])
m3=pd.merge(m2,n7,how='left',on=['Strike Price'])
m3=m3.rename(columns={'Close_x':'07-Jan-2019','Close_y':'08-Jan-2019'})
m4=pd.merge(m3,n8,how='left',on=['Strike Price'])
m5=pd.merge(m4,n9,how='left',on=['Strike Price'])
m5=m5.rename(columns={'Close_x':end_date,'Close_y':'10-Jan-2019'})

m5['Expiry']='10-Jan-2019'

# %%
n3

# %%
m1['03-Jan-2019']=m1['Close_x']
m1['04-Jan-2019']=m1['Close_y']
print(m1)

# %%
#trials

# %%
 from datetime import date, timedelta
