# %% [markdown]
# # Top 10 Customers with Sales Amount based on Net Value

# %%
import numpy as np
import pandas

# %%
import os
os.chdir("C:\\Users\\bired\\Desktop\\sales ds")

# %%
pwd
# Out:
# 'C:\\Users\\bired\\Desktop\\sales ds'

# %%
import pandas
df = pandas.read_csv("new_sale.csv")

# %%
df.head()
# Out:
#   Retailer country Order method type  Retailer type       Product line  \
# 0    United States               Fax  Outdoors Shop  Camping Equipment
# 1    United States               Fax  Outdoors Shop  Camping Equipment
# 2    United States               Fax  Outdoors Shop  Camping Equipment
# 3    United States               Fax  Outdoors Shop  Camping Equipment
# 4    United States               Fax  Outdoors Shop  Camping Equipment
#
#     Product type                    Product  Year  Quarter    Revenue  \
# 0   Cooking Gear  TrailChef Deluxe Cook Set  2012  Q1 2012   59628.66
# 1   Cooking Gear     TrailChef Double Flame  2012  Q1 2012   35950.32
# 2          Tents                  Star Dome  2012  Q1 2012   89940.48
# 3          Tents               Star Gazer 2  2012  Q1 2012  165883.41
# 4  Sleeping Bags            Hibernator Lite  2012  Q1 2012  119822.20
#
#    Quantity  Gross margin
# 0       489      0.347548
# 1       252      0.474274
# 2       147      0.352772
# ...

# %%
df.shape
# Out:
# (88475, 11)

# %%
df.iloc[0,8]
# Out:
# 59628.66

# %%
booldf=df.Quantity>2000

# %%
df[booldf]
# Out:
#       Retailer country Order method type     Retailer type  \
# 19       United States               Fax     Outdoors Shop
# 38       United States               Fax     Outdoors Shop
# 73       United States         Telephone  Department Store
# 74       United States         Telephone  Department Store
# 75       United States         Telephone  Department Store
# 79       United States         Telephone  Department Store
# 89       United States         Telephone  Department Store
# 97       United States         Telephone  Department Store
# 98       United States         Telephone  Department Store
# 104      United States         Telephone  Department Store
# 127      United States         Telephone  Department Store
# 136      United States         Telephone  Department Store
# 139      United States         Telephone  Department Store
# 140      United States         Telephone  Department Store
# 141      United States         Telephone  Department Store
# ...

# %%
df.columns
# Out:
# Index(['Retailer country', 'Order method type', 'Retailer type',
#        'Product line', 'Product type', 'Product', 'Year', 'Quarter', 'Revenue',
#        'Quantity', 'Gross margin'],
#       dtype='object')

# %%
df.Quantity.mean()
# Out:
# 780.5861655834982

# %%
# summary statistics
print(df.describe())
# Out:
#                Year       Revenue      Quantity  Gross margin
# count  88475.000000  8.847500e+04  88475.000000  87894.000000
# mean    2012.855281  4.263829e+04    780.586166      0.449718
# std        0.778342  6.578402e+04   1541.645422      0.123642
# min     2012.000000  0.000000e+00      1.000000    -12.853678
# 25%     2012.000000  8.184360e+03    131.000000      0.369880
# 50%     2013.000000  2.102628e+04    333.000000      0.450634
# 75%     2013.000000  5.039060e+04    816.000000      0.520130
# max     2014.000000  1.635688e+06  67875.000000      0.770476

# %%
df = df.rename(columns = {"Product": "customer", 
                                  "Gross margin":"Netvalue","Revenue":"sales amount"})

# %%
#1. Customer Growth rate Vs Customers Count                                              
# Top 10 Customers with Sales Amount based on Net Value     
#. Quarterly Customer Growth Trend                                                                                                      
#. Open Invoice vs Available Credits by Customer

# %%
df['sales amount'].max()
# Out:
# 1635687.96

# %%
#finding top10 customers with sales

# %%
# sorting in descending order 
df.sort_values('sales amount',ascending=False)
# Out:
#       Retailer country Order method type           Retailer type  \
# 67651    United States               Web            Sports Store
# 75941    United States               Web            Sports Store
# 43029    United States               Web            Sports Store
# 75616    United States               Web               Golf Shop
# 59525    United States               Web         Warehouse Store
# 43030    United States               Web            Sports Store
# 59631    United States               Web           Outdoors Shop
# 42670    United States               Web               Golf Shop
# 164      United States         Telephone         Warehouse Store
# 42879    United States               Web           Outdoors Shop
# 42944    United States               Web           Outdoors Shop
# 70217            China               Web               Golf Shop
# 59523    United States               Web         Warehouse Store
# ...

# %%
df.groupby("customer").sum().sort_values("sales amount", ascending=False).head(10)
# Out:
#                                  Year  sales amount  Quantity    Netvalue
# customer
# Star Lite                     1270104  1.335134e+08    377806  185.326660
# Zone                          2244352  1.245424e+08   3883067  366.423488
# Star Gazer 2                  1159376  1.169150e+08    212040  165.541096
# Hailstorm Titanium Woods Set   970205  9.574956e+07     80279  224.103940
# Inferno                       2204105  8.965392e+07   1343144  458.577990
# Infinity                      2208121  8.944453e+07    380159  498.310813
# TX                            2244340  8.302556e+07    438065  505.933990
# Maximus                       2196047  8.023710e+07    951349  546.397954
# Canyon Mule Journey Backpack  1388928  7.983404e+07    232265  259.457649
# Hailstorm Titanium Irons      1042664  7.546148e+07     88114  240.245302
