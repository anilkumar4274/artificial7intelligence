# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\MAHE\\Desktop\\Data Science'

# %% [markdown]
# # All stocks:

# %%
#Load the dataframe 
import numpy as np
import pandas as pd
import requests
import re
import pandas as pd
from bs4 import BeautifulSoup
Base_url=("https://zerodha.com/margin-calculator/Equity/")
page=requests.get(Base_url)
soup=BeautifulSoup(page.content,'html.parser')
data = []
table = soup.find('table', attrs={'class':'data equity'})
table_body = table.find('tbody')

rows = soup.find_all('tr')
for row in rows:
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    data.append([ele for ele in cols if ele]) # Get rid of empty values

df = pd.DataFrame(data = data)





#LIST COMPREHESNION
company_symbol = []
[company_symbol.append(df.loc[i][1][:-3:]) for i in range(len(df)) if df.loc[i][3] == "12.5x"]
company_symbol
# Out:
# ['ACC',
#  'AMARAJABAT',
#  'AMBUJACEM',
#  'APOLLOTYRE',
#  'ASIANPAINT',
#  'AUROPHARMA',
#  'AXISBANK',
#  'BAJAJ-AUTO',
#  'BAJAJFINSV',
#  'BAJFINANCE',
#  'BALKRISIND',
#  'BANKBARODA',
#  'BATAINDIA',
#  'BEL',
#  'BERGEPAINT',
#  'BHARATFORG',
#  'BIOCON',
#  'BOSCHLTD',
#  'BPCL',
#  'BRITANNIA',
#  'CADILAHC',
#  'CANBK',
#  'CASTROLIND',
#  'CENTURYTEX',
#  'CESC',
#  'CHOLAFIN',
#  'CIPLA',
#  'COALINDIA',
#  'COLPAL',
#  'CONCOR',
#  'CUMMINSIND',
#  'DABUR',
#  'EICHERMOT',
#  'ENGINERSIN',
#  'ESCORTS',
#  'EXIDEIND',
#  'FEDERALBNK',
#  'GLENMARK',
#  'GODREJCP',
#  'GRASIM',
#  'HAVELLS',
#  'HCLTECH',
#  'HDFC',
#  'HDFCBANK',
#  'HEROMOTOCO',
#  'HEXAWARE',
#  'HINDALCO',
#  'HINDUNILVR',
#  'HINDZINC',
#  'ICICIBANK',
#  'IDBI',
#  'IGL',
#  'INDUSINDBK',
#  'INFRATEL',
#  'INFY',
#  'ITC',
#  'JSWSTEEL',
#  'KAJARIACER',
#  'KOTAKBANK',
#  'LICHSGFIN',
#  'LT',
#  'LUPIN',
#  'M&M',
#  'MANAPPURAM',
#  'MARICO',
#  'MARUTI',
#  'MCDOWELL-N',
#  'MCX',
#  'MFSL',
#  'MGL',
#  'MINDTREE',
#  'MRF',
#  'MUTHOOTFIN',
#  'NATIONALUM',
#  'NBCC',
#  'NCC',
#  'NESTLEIND',
#  'NIITTECH',
#  'NMDC',
#  'NTPC',
#  'OFSS',
#  'OIL',
#  'ONGC',
#  'PEL',
#  'PETRONET',
#  'PIDILITIND',
#  'POWERGRID',
#  'PVR',
#  'RAMCOCEM',
#  'RAYMOND',
#  'RECLTD',
#  'RELIANCE',
#  'SAIL',
#  'SBIN',
#  'SHREECEM',
#  'SIEMENS',
#  'TATACHEM',
#  'TATAELXSI',
#  'TATAGLOBAL',
#  'TATAPOWER',
#  'TATASTEEL',
#  'TCS',
#  'TECHM',
#  'TORNTPHARM',
#  'TORNTPOWER',
#  'TVSMOTOR',
#  'UBL',
#  'ULTRACEMCO',
#  'UPL',
#  'VOLTAS',
#  'WIPRO']

# %%
company_symbol[:10]
# Out:
# ['ACC',
#  'AMARAJABAT',
#  'AMBUJACEM',
#  'APOLLOTYRE',
#  'ASIANPAINT',
#  'AUROPHARMA',
#  'AXISBANK',
#  'BAJAJ-AUTO',
#  'BAJAJFINSV',
#  'BAJFINANCE']

# %%
def job_function2():
    import pandas as pd
    import numpy as np
    import datetime
    import time
    import subprocess
    baseURL='https://www.nseindia.com/live_market/dynaContent/live_watch/get_quote/GetQuote.jsp?symbol='
    symbol_list = []
    buy_list = []
    sell_list = []
    lastP_list = []
    for i in company_symbol[:10]:
        textfile = subprocess.check_output(['curl','-o',i+'.txt','-O', baseURL+i])
        f = open(i+".txt","r")
        file = str(f.read())
        beg = file.find('[{')
        end = file.find('}]')
        trial = file[beg+1:end+1]
        trial = trial.replace('false','"false"').replace('true','"true"')
        trial = eval(trial)  
        symbol_list.append(trial["symbol"])
        buy_list.append(trial["totalBuyQuantity"])
        sell_list.append(trial["totalSellQuantity"])
        lastP_list.append(trial["lastPrice"])

    global count, scheduler

    df["symbol"] = symbol_list
    df["buy"] = buy_list
    df["sell"] = sell_list
    df["lastP"] = lastP_list

    #df = pd.DataFrame({"symbol":,"buy":[trial["totalBuyQuantity"]],"sell":[trial["totalSellQuantity"]],"lastP":[trial["lastPrice"]]})
    df['sell']=[x.replace('-','0').replace(',','') for x in df['sell']]
    df['buy']=[x.replace('-','0').replace(',','') for x in df['buy']]
    currentDT = datetime.datetime.now()
    df['time']=currentDT.strftime("%H:%M")
    if count==0:
        df["bs"+str(count)] = np.where(df["sell"]>=df["buy"],"S","B")
    else:
        df["bs"+str(count)] = np.where(df["sell"]>=df["buy"],"S","B")
        result["bs"+str(count)] = np.where(df["bs"+str(count)]==df["bs"+str(count-1)],"S",df["symbol"]+df["time"])
        
    df["size"] = ["S" if float(df.loc[i]["sell"])>float(df.loc[i]["buy"]) else "B" for i in range(10)]
    
    df["times_greater"] = [float(df.loc[i]["sell"])/float(df.loc[i]["buy"]) if df.loc[i]["size"]=="S" else float(df.loc[i]["buy"])/float(df.loc[i]["sell"]) for i in range(10)]

    df.to_csv("all"+str(count)+".csv")
    
    count+=1

    if count==20:
        scheduler.shutdown(wait = False)

# %%
from datetime import datetime
from apscheduler.schedulers.background import BackgroundScheduler
count = 0
df = pd.DataFrame(columns = ["symbol","buy","sell","size","times_greater","lastP","time"]) 
result = pd.DataFrame(columns = ["symbol"])
scheduler = BackgroundScheduler()

scheduler.add_job(job_function2, 'interval', minutes = 2, start_date='2019-08-13 10:55:00', end_date='2019-08-13 11:05:00', id='my_job_id')

try:
    scheduler.start()
except apscheduler.schedulers.SchedulerNotRunningError as e:
    print('program exited')
# Out:
# Job "job_function2 (trigger: interval[0:02:00], next run at: 2019-08-13 11:03:00 IST)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\MAHE\Anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-ed6b4ba01d50>", line 13, in job_function2
#     textfile = subprocess.check_output(['curl','-o',i+'.txt','-O', baseURL+i])
#   File "C:\Users\MAHE\Anaconda3\lib\subprocess.py", line 395, in check_output
#     **kwargs).stdout
#   File "C:\Users\MAHE\Anaconda3\lib\subprocess.py", line 487, in run
#     output=stdout, stderr=stderr)
# subprocess.CalledProcessError: Command '['curl', '-o', 'ACC.txt', '-O', 'https://www.nseindia.com/live_market/dynaContent/live_watch/get_quote/GetQuote.jsp?symbol=ACC']' returned non-zero exit status 6.
# Job "job_function2 (trigger: interval[0:02:00], next run at: 2019-08-13 11:05:00 IST)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\MAHE\Anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-ed6b4ba01d50>", line 13, in job_function2
#     textfile = subprocess.check_output(['curl','-o',i+'.txt','-O', baseURL+i])
#   File "C:\Users\MAHE\Anaconda3\lib\subprocess.py", line 395, in check_output
#     **kwargs).stdout
#   File "C:\Users\MAHE\Anaconda3\lib\subprocess.py", line 487, in run
#     output=stdout, stderr=stderr)
# subprocess.CalledProcessError: Command '['curl', '-o', 'ACC.txt', '-O', 'https://www.nseindia.com/live_market/dynaContent/live_watch/get_quote/GetQuote.jsp?symbol=ACC']' returned non-zero exit status 6.
# Job "job_function2 (trigger: interval[0:02:00], next run at: 2019-08-13 11:05:00 IST)" raised an exception
# Traceback (most recent call last):
#   File "C:\Users\MAHE\Anaconda3\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-ed6b4ba01d50>", line 13, in job_function2
#     textfile = subprocess.check_output(['curl','-o',i+'.txt','-O', baseURL+i])
#   File "C:\Users\MAHE\Anaconda3\lib\subprocess.py", line 395, in check_output
#     **kwargs).stdout
#   File "C:\Users\MAHE\Anaconda3\lib\subprocess.py", line 487, in run
#     output=stdout, stderr=stderr)
# subprocess.CalledProcessError: Command '['curl', '-o', 'ACC.txt', '-O', 'https://www.nseindia.com/live_market/dynaContent/live_watch/get_quote/GetQuote.jsp?symbol=ACC']' returned non-zero exit status 6.
