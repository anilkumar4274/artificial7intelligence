# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as snss

# %%
df=pd.read_csv('GermanCredit.csv')

# %%
df.head()
# Out:
#                 status  duration                            credit_history  \
# 0         ... < 100 DM         6   critical account/other credits existing
# 1    0 <= ... < 200 DM        48  existing credits paid back duly till now
# 2  no checking account        12   critical account/other credits existing
# 3         ... < 100 DM        42  existing credits paid back duly till now
# 4         ... < 100 DM        24           delay in paying off in the past
#
#                purpose  amount                     savings  \
# 0  domestic appliances    1169  unknown/no savings account
# 1  domestic appliances    5951                ... < 100 DM
# 2           retraining    2096                ... < 100 DM
# 3     radio/television    7882                ... < 100 DM
# 4            car (new)    4870                ... < 100 DM
#
#   employment_duration  installment_rate                  personal_status_sex  \
# 0      ... >= 7 years                 4                        male : single
# ...

# %%
print(df.shape)
df.columns
# Out:
# (90, 23)
# Index(['status', 'duration', 'credit_history', 'purpose', 'amount', 'savings',
#        'employment_duration', 'installment_rate', 'personal_status_sex',
#        'other_debtors', 'present_residence', 'property', 'age',
#        'other_installment_plans', 'housing', 'number_credits', 'job',
#        'people_liable', 'telephone', 'foreign_worker', 'credit_risk', 'Yrows',
#        'Xcols'],
#       dtype='object')

# %%
df.drop(['savings','employment_duration', 'installment_rate', 'personal_status_sex','other_debtors', 'present_residence', 'property', 'age','other_installment_plans', 'housing', 'number_credits', 'job','people_liable', 'telephone', 'foreign_worker', 'credit_risk', 'credit_history'],axis=1,inplace=True)

# %%
df.head()
# Out:
#                 status  duration              purpose  amount  Yrows  Xcols
# 0         ... < 100 DM         6  domestic appliances    1169      1      1
# 1    0 <= ... < 200 DM        48  domestic appliances    5951      1      2
# 2  no checking account        12           retraining    2096      1      3
# 3         ... < 100 DM        42     radio/television    7882      1      4
# 4         ... < 100 DM        24            car (new)    4870      1      5

# %%
Status=(np.asarray(df['status'])).reshape(9,10);Status
# Out:
# array([['... < 100 DM', '0 <= ... < 200 DM', 'no checking account',
#         '... < 100 DM', '... < 100 DM', 'no checking account',
#         'no checking account', '0 <= ... < 200 DM',
#         'no checking account', '0 <= ... < 200 DM'],
#        ['0 <= ... < 200 DM', '... < 100 DM', '0 <= ... < 200 DM',
#         '... < 100 DM', '... < 100 DM', '... < 100 DM',
#         'no checking account', '... < 100 DM', '0 <= ... < 200 DM',
#         'no checking account'],
#        ['no checking account', '... < 100 DM', '... < 100 DM',
#         '0 <= ... < 200 DM', 'no checking account', '... < 100 DM',
#         'no checking account',
#         '... >= 200 DM / salary for at least 1 year',
#         '0 <= ... < 200 DM', '... < 100 DM'],
#        ['0 <= ... < 200 DM', '... < 100 DM', '0 <= ... < 200 DM',
#         'no checking account',
#         '... >= 200 DM / salary for at least 1 year',
#         '0 <= ... < 200 DM', 'no checking account',
# ...

# %%
Duration=(np.asarray(df['duration'])).reshape(9,10);Duration
# Out:
# array([[ 6, 48, 12, 42, 24, 36, 24, 36, 12, 30],
#        [12, 48, 12, 24, 15, 24, 24, 30, 24, 24],
#        [ 9,  6, 10, 12, 10,  6,  6, 12,  7, 60],
#        [18, 24, 18, 12, 12, 45, 48, 18, 10,  9],
#        [30, 12, 18, 30, 48, 11, 36,  6, 11, 12],
#        [24, 27, 12, 18, 36,  6, 12, 36, 18, 36],
#        [ 9, 15, 36, 48, 24, 27, 12, 12, 36, 36],
#        [36,  7,  8, 42, 36, 12, 42, 11, 54, 30],
#        [24, 15, 18, 24, 10, 12, 18, 36, 18, 12]], dtype=int64)

# %%
Purpose=(np.asarray(df['purpose'])).reshape(9,10);Purpose
# Out:
# array([['domestic appliances', 'domestic appliances', 'retraining',
#         'radio/television', 'car (new)', 'retraining',
#         'radio/television', 'car (used)', 'domestic appliances',
#         'car (new)'],
#        ['car (new)', 'others', 'domestic appliances', 'car (new)',
#         'car (new)', 'domestic appliances', 'domestic appliances',
#         'others', 'car (used)', 'domestic appliances'],
#        ['car (new)', 'domestic appliances', 'car (new)', 'car (used)',
#         'radio/television', 'radio/television', 'domestic appliances',
#         'domestic appliances', 'domestic appliances', 'others'],
#        ['others', 'radio/television', 'car (new)', 'others',
#         'radio/television', 'domestic appliances', 'retraining',
#         'domestic appliances', 'repairs', 'domestic appliances'],
#        ['domestic appliances', 'domestic appliances', 'education',
#         'car (used)', 'car (used)', 'car (new)', 'domestic appliances',
# ...

# %%
Amount=(np.asarray(df['amount'])).reshape(9,10);Amount
# Out:
# array([[ 1169,  5951,  2096,  7882,  4870,  9055,  2835,  6948,  3059,
#          5234],
#        [ 1295,  4308,  1567,  1199,  1403,  1282,  2424,  8072, 12579,
#          3430],
#        [ 2134,  2647,  2241,  1804,  2069,  1374,   426,   409,  2415,
#          6836],
#        [ 1913,  4020,  5866,  1264,  1474,  4746,  6110,  2100,  1225,
#           458],
#        [ 2333,  1158,  6204,  6187,  6143,  1393,  2299,  1352,  7228,
#          2073],
#        [ 2333,  5965,  1262,  3378,  2225,   783,  6468,  9566,  1961,
#          6229],
#        [ 1391,  1537,  1953, 14421,  3181,  5190,  2171,  1007,  1819,
#          2394],
#        [ 8133,   730,  1164,  5954,  1977,  1526,  3965,  4771,  9436,
#          3832],
#        [ 5943,  1213,  1568,  1755,  2315,  1412,  1295, 12612,  2249,
#          1108]], dtype=int64)

# %%
result=df.pivot(index='Yrows',columns='Xcols',values='amount');result
# Out:
# Xcols     1     2      3      4     5
# Yrows
# 1      1169  5951   2096   7882  4870
# 2      9055  2835   6948   3059  5234
# 3      1295  4308   1567   1199  1403
# 4      1282  2424   8072  12579  3430
# 5      2134  2647   2241   1804  2069
# 6      1374   426    409   2415  6836
# 7      1913  4020   5866   1264  1474
# 8      4746  6110   2100   1225   458
# 9      2333  1158   6204   6187  6143
# 10     1393  2299   1352   7228  2073
# 11     2333  5965   1262   3378  2225
# 12      783  6468   9566   1961  6229
# 13     1391  1537   1953  14421  3181
# 14     5190  2171   1007   1819  2394
# 15     8133   730   1164   5954  1977
# 16     1526  3965   4771   9436  3832
# 17     5943  1213   1568   1755  2315
# 18     1412  1295  12612   2249  1108

# %%
labels=(np.asarray(["{0} \n {1} \n {2} \n {3}".format(sta,dura,pur,amo) 
                   for sta,dura,pur,amo in zip(Status.flatten(),Duration.flatten(),Purpose.flatten(),Amount.flatten())])).reshape(18,5,)
labels
# Out:
# array([['... < 100 DM \n 6 \n domestic appliances \n 1169',
#         '0 <= ... < 200 DM \n 48 \n domestic appliances \n 5951',
#         'no checking account \n 12 \n retraining \n 2096',
#         '... < 100 DM \n 42 \n radio/television \n 7882',
#         '... < 100 DM \n 24 \n car (new) \n 4870'],
#        ['no checking account \n 36 \n retraining \n 9055',
#         'no checking account \n 24 \n radio/television \n 2835',
#         '0 <= ... < 200 DM \n 36 \n car (used) \n 6948',
#         'no checking account \n 12 \n domestic appliances \n 3059',
#         '0 <= ... < 200 DM \n 30 \n car (new) \n 5234'],
#        ['0 <= ... < 200 DM \n 12 \n car (new) \n 1295',
#         '... < 100 DM \n 48 \n others \n 4308',
#         '0 <= ... < 200 DM \n 12 \n domestic appliances \n 1567',
#         '... < 100 DM \n 24 \n car (new) \n 1199',
#         '... < 100 DM \n 15 \n car (new) \n 1403'],
#        ['... < 100 DM \n 24 \n domestic appliances \n 1282',
# ...

# %%
fig,ax=plt.subplots(figsize=(20,19))

#ADD TITLE TO THE HEAT MAP
title="GermanCredit"

#SET THE FONT SIZE AND THE DIsTANCE OF THE TITLE FROM THE plOT
plt.title(title,fontsize=18)
ttl=ax.title
ttl.set_position([0.5,1.05])

#HIDE TICKS FOR X AND Y AXIS
ax.set_xticks([])
ax.set_yticks([])

#REMOVE THE AXIS
ax.axis('off')
#fig,ax=plt.subplots(figsize=(12,12))
snss.heatmap(result,annot=labels,fmt="",cmap='gist_rainbow',linewidths=0.30,linecolor='green',ax=ax)
plt.show()

# %%
from IPython.display import set_matplotlib_formats
set_matplotlib_formats("svg")

#DEFINE THE PLOT
fig,ax=plt.subplots(figsize=(20,17))

#ADD TITLE TO THE HEAT MAP
title="diamonds"

#SET THE FONT SIZE AND THE DIsTANCE OF THE TITLE FROM THE plOT
plt.title(title,fontsize=18)
ttl=ax.title
ttl.set_position([0.5,1.05])

#HIDE TICKS FOR X AND Y AXIS
ax.set_xticks([])
ax.set_yticks([])
ax.axis('off')

im=ax.imshow(result)
fig.colorbar(im)
for (j,i), x in np.ndenumerate(result):
    url = "https://www.google.com/search?q=german+credit+data+analysis&oq=GermanCredit&aqs=chrome.1.69i57j0l5.12232j1j7&sourceid=chrome&ie=UTF-8"
    ax.annotate(x, xy=(i,j), ha="center", va="center",
                url=url, bbox=dict(color='r', alpha=1e-6, url=url)) 
plt.show()
