# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Dell\\Desktop\\Data Science\\python3'

# %%
os.chdir('C:\\Users\\Dell\\Desktop\\Data Science\\python3')

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '16072019',
#  'july 16.ipynb',
#  'monday.csv',
#  'pandaas',
#  'pandas.ipynb',
#  'test.csv',
#  'test.tsv',
#  'test.xlsx',
#  'titanic.csv',
#  'untitled',
#  'Untitled Folder',
#  'untitled.txt']

# %%
import pandas as pd

# %%
df=pd.read_csv('test.csv')
df.to_csv('monday.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a669bf42234e> in <module>
# ----> 1 df=pd.read_csv('test.csv')
#       2 df.to_csv('monday.csv')
#
# NameError: name 'pd' is not defined

# %%
df
# Out:
#       Rk                 Player Pos  Age   Tm   G    MP   PER    TS%   3PAr  \
# 0      1             Quincy Acy  PF   24  NYK  68  1287  11.9  0.533  0.181
# 1      2           Jordan Adams  SG   20  MEM  30   248  12.8  0.489  0.291
# 2      3           Steven Adams   C   21  OKC  70  1771  14.1  0.549  0.005
# 3      4            Jeff Adrien  PF   28  MIN  17   215  14.2  0.494  0.000
# 4      5          Arron Afflalo  SG   29  TOT  78  2502  10.7  0.533  0.377
# 5      5          Arron Afflalo  SG   29  DEN  53  1750  11.7  0.533  0.370
# 6      5          Arron Afflalo  SG   29  POR  25   752   8.2  0.533  0.396
# 7      6          Alexis Ajinca   C   26  NOP  68   957  19.9  0.595  0.000
# 8      7         Furkan Aldemir  PF   23  PHI  41   540  12.0  0.517  0.064
# 9      8           Cole Aldrich   C   26  NYK  61   976  18.1  0.513  0.000
# 10     9      LaMarcus Aldridge  PF   29  POR  71  2512  22.8  0.528  0.074
# ...

# %%
df.shape
# Out:
# (651, 29)

# %%
df.head(7)
# Out:
#    Rk         Player Pos  Age   Tm   G    MP   PER    TS%   3PAr  ...  \
# 0   1     Quincy Acy  PF   24  NYK  68  1287  11.9  0.533  0.181  ...
# 1   2   Jordan Adams  SG   20  MEM  30   248  12.8  0.489  0.291  ...
# 2   3   Steven Adams   C   21  OKC  70  1771  14.1  0.549  0.005  ...
# 3   4    Jeff Adrien  PF   28  MIN  17   215  14.2  0.494  0.000  ...
# 4   5  Arron Afflalo  SG   29  TOT  78  2502  10.7  0.533  0.377  ...
# 5   5  Arron Afflalo  SG   29  DEN  53  1750  11.7  0.533  0.370  ...
# 6   5  Arron Afflalo  SG   29  POR  25   752   8.2  0.533  0.396  ...
#
#    Unnamed: 19  OWS  DWS   WS  WS/48  Unnamed: 24  OBPM  DBPM  BPM  VORP
# 0          NaN  1.0  0.7  1.7  0.063          NaN  -2.3  -0.8 -3.1  -0.3
# 1          NaN  0.0  0.4  0.4  0.073          NaN  -1.8   1.2 -0.6   0.1
# 2          NaN  1.9  2.2  4.1  0.111          NaN  -1.4   1.8  0.4   1.1
# 3          NaN  0.2  0.2  0.4  0.087          NaN  -2.7   0.5 -2.2   0.0
# ...

# %%
df_t=pd.read_csv('test.tsv',sep='\t')

# %%
df_t.head()
# Out:
#    Rk         Player Pos  Age   Tm   G    MP   PER    TS%   3PAr  ...  \
# 0   1     Quincy Acy  PF   24  NYK  68  1287  11.9  0.533  0.181  ...
# 1   2   Jordan Adams  SG   20  MEM  30   248  12.8  0.489  0.291  ...
# 2   3   Steven Adams   C   21  OKC  70  1771  14.1  0.549  0.005  ...
# 3   4    Jeff Adrien  PF   28  MIN  17   215  14.2  0.494  0.000  ...
# 4   5  Arron Afflalo  SG   29  TOT  78  2502  10.7  0.533  0.377  ...
#
#    Unnamed: 19  OWS  DWS   WS  WS/48  Unnamed: 24  OBPM  DBPM  BPM  VORP
# 0          NaN  1.0  0.7  1.7  0.063          NaN  -2.3  -0.8 -3.1  -0.3
# 1          NaN  0.0  0.4  0.4  0.073          NaN  -1.8   1.2 -0.6   0.1
# 2          NaN  1.9  2.2  4.1  0.111          NaN  -1.4   1.8  0.4   1.1
# 3          NaN  0.2  0.2  0.4  0.087          NaN  -2.7   0.5 -2.2   0.0
# 4          NaN  1.6  1.0  2.6  0.050          NaN  -0.5  -1.3 -1.8   0.1
#
# [5 rows x 29 columns]

# %%
df.shape
# Out:
# (651, 29)

# %%
df3=pd.read_excel('test.xlsx',sheet_name='Sheet1')
df3.head()
# Out:
#    Rk         Player Pos  Age   Tm   G    MP   PER    TS%   3PAr  ...  \
# 0   1     Quincy Acy  PF   24  NYK  68  1287  11.9  0.533  0.181  ...
# 1   2   Jordan Adams  SG   20  MEM  30   248  12.8  0.489  0.291  ...
# 2   3   Steven Adams   C   21  OKC  70  1771  14.1  0.549  0.005  ...
# 3   4    Jeff Adrien  PF   28  MIN  17   215  14.2  0.494  0.000  ...
# 4   5  Arron Afflalo  SG   29  TOT  78  2502  10.7  0.533  0.377  ...
#
#    Unnamed: 19  OWS  DWS   WS  WS/48  Unnamed: 24  OBPM  DBPM  BPM  VORP
# 0          NaN  1.0  0.7  1.7  0.063          NaN  -2.3  -0.8 -3.1  -0.3
# 1          NaN  0.0  0.4  0.4  0.073          NaN  -1.8   1.2 -0.6   0.1
# 2          NaN  1.9  2.2  4.1  0.111          NaN  -1.4   1.8  0.4   1.1
# 3          NaN  0.2  0.2  0.4  0.087          NaN  -2.7   0.5 -2.2   0.0
# 4          NaN  1.6  1.0  2.6  0.050          NaN  -0.5  -1.3 -1.8   0.1
#
# [5 rows x 29 columns]

# %%
df4=pd.read_clipboard(sep="\t")
df4.head()
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# <ipython-input-61-ba56f6d6e2ac> in <module>
# ----> 1 df4=pd.read_clipboard(sep="\t")
#       2 df4.head()
#
# ~\Anaconda3\lib\site-packages\pandas\io\clipboards.py in read_clipboard(sep, **kwargs)
#      83         text = text.encode('utf-8')
#      84
# ---> 85     return read_csv(StringIO(text), sep=sep, **kwargs)
#      86
#      87
#
# ...

# %%
type(df4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-1febe824b032> in <module>
# ----> 1 type(df4)
#
# NameError: name 'df4' is not defined

# %%
url="http://www.basketball-reference.com/leagues/NBA_2015_totals.html"
df6=pd.read_html(url)
df6.head()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# ~\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# ~\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv('titanic.csv',sep='\t')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (156, 12)

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe()
# Out:
#                Rk         Age           G           MP         PER  \
# count  651.000000  651.000000  651.000000   651.000000  651.000000
# mean   256.520737   26.500768   45.960061  1041.775730   12.549155
# std    143.081604    4.110914   25.503151   806.253103    6.457614
# min      1.000000   19.000000    1.000000     1.000000  -41.700000
# 25%    130.500000   23.000000   24.000000   272.000000    9.700000
# 50%    262.000000   26.000000   48.000000   896.000000   12.500000
# 75%    381.500000   29.000000   70.000000  1674.000000   15.800000
# max    492.000000   38.000000   83.000000  2981.000000   44.300000
#
#               TS%        3PAr         FTr        ORB%        DRB%  ...  \
# count  649.000000  649.000000  649.000000  651.000000  651.000000  ...
# mean     0.505974    0.281766    0.265861    5.101843   14.214286  ...
# std      0.097621    0.221529    0.183590    4.346372    6.929651  ...
# min      0.000000    0.000000    0.000000    0.000000    0.000000  ...
# ...

# %%
categorical=df.dtypes[df.dtypes=="object"].index
print(categorical)
# Out:
# Index(['Player', 'Pos', 'Tm'], dtype='object')

# %%
df.dtypes=="int64"
# Out:
# Rk              True
# Player         False
# Pos            False
# Age             True
# Tm             False
# G               True
# MP              True
# PER            False
# TS%            False
# 3PAr           False
# FTr            False
# ORB%           False
# DRB%           False
# TRB%           False
# AST%           False
# STL%           False
# BLK%           False
# TOV%           False
# USG%           False
# Unnamed: 19    False
# OWS            False
# DWS            False
# WS             False
# WS/48          False
# Unnamed: 24    False
# OBPM           False
# DBPM           False
# BPM            False
# VORP           False
# dtype: bool

# %%
df.dtypes=="object"
# Out:
# Rk             False
# Player          True
# Pos             True
# Age            False
# Tm              True
# G              False
# MP             False
# PER            False
# TS%            False
# 3PAr           False
# FTr            False
# ORB%           False
# DRB%           False
# TRB%           False
# AST%           False
# STL%           False
# BLK%           False
# TOV%           False
# USG%           False
# Unnamed: 19    False
# OWS            False
# DWS            False
# WS             False
# WS/48          False
# Unnamed: 24    False
# OBPM           False
# DBPM           False
# BPM            False
# VORP           False
# dtype: bool

# %%
df.dtypes[df.dtypes=="object"]
# Out:
# Player    object
# Pos       object
# Tm        object
# dtype: object

# %%
df.dtypes[df.dtypes=="object"].index
# Out:
# Index(['Player', 'Pos', 'Tm'], dtype='object')

# %%
df.Name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-1f0c583f0f8f> in <module>
# ----> 1 df.Name
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Name'

# %%
df[['Ticket','Cabin']] #select two columns at a time
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-8d8655c18c67> in <module>
# ----> 1 df[['Ticket','Cabin']] #select two columns at a time
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1355         else:
#    1356             try:
# ...

# %%
df[categorical].describe()
# Out:
#             Player  Pos   Tm
# count          651  651  651
# unique         492   11   31
# top     A.J. Price   SG  TOT
# freq             4  143   76

# %%
del df['PassengerId'] #deleting the particular column
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PassengerId'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-fc71697b7628> in <module>
# ...

# %%
df.head()
# Out:
#    Rk         Player Pos  Age   Tm   G    MP   PER    TS%   3PAr  ...  \
# 0   1     Quincy Acy  PF   24  NYK  68  1287  11.9  0.533  0.181  ...
# 1   2   Jordan Adams  SG   20  MEM  30   248  12.8  0.489  0.291  ...
# 2   3   Steven Adams   C   21  OKC  70  1771  14.1  0.549  0.005  ...
# 3   4    Jeff Adrien  PF   28  MIN  17   215  14.2  0.494  0.000  ...
# 4   5  Arron Afflalo  SG   29  TOT  78  2502  10.7  0.533  0.377  ...
#
#    Unnamed: 19  OWS  DWS   WS  WS/48  Unnamed: 24  OBPM  DBPM  BPM  VORP
# 0          NaN  1.0  0.7  1.7  0.063          NaN  -2.3  -0.8 -3.1  -0.3
# 1          NaN  0.0  0.4  0.4  0.073          NaN  -1.8   1.2 -0.6   0.1
# 2          NaN  1.9  2.2  4.1  0.111          NaN  -1.4   1.8  0.4   1.1
# 3          NaN  0.2  0.2  0.4  0.087          NaN  -2.7   0.5 -2.2   0.0
# 4          NaN  1.6  1.0  2.6  0.050          NaN  -0.5  -1.3 -1.8   0.1
#
# [5 rows x 29 columns]

# %%
sorted(df['Name'])[0:10]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-26b715c608e5> in <module>
# ----> 1 sorted(df['Name'])[0:10]
#
# ...

# %%
#deleting more than one column "del df[''],df ['']"

# %%
df['Name'].describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-fe28f7ea1024> in <module>
# ----> 1 df['Name'].describe()
#
# ...

# %%
df['Ticket']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ticket'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-319a08e207c5> in <module>
# ----> 1 df['Ticket']
#
# ...

# %%
type(df['Ticket'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ticket'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-1bbf29e002e9> in <module>
# ----> 1 type(df['Ticket'])
#
# ...

# %%
df['Ticket'].head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ticket'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-3b8df3f0072f> in <module>
# ----> 1 df['Ticket'].head(10)
#
# ...

# %%
df['Ticket'][0:10] #first 10 elements
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ticket'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-146d258d51ef> in <module>
# ----> 1 df['Ticket'][0:10] #first 10 elements
#
# ...

# %%
sorted(df['Name'])[0:15]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-ce8a4eef0763> in <module>
# ----> 1 sorted(df['Name'])[0:15]
#
# ...

# %%
df.dtypes
# Out:
# Rk               int64
# Player          object
# Pos             object
# Age              int64
# Tm              object
# G                int64
# MP               int64
# PER            float64
# TS%            float64
# 3PAr           float64
# FTr            float64
# ORB%           float64
# DRB%           float64
# TRB%           float64
# AST%           float64
# STL%           float64
# BLK%           float64
# TOV%           float64
# USG%           float64
# Unnamed: 19    float64
# OWS            float64
# DWS            float64
# WS             float64
# WS/48          float64
# Unnamed: 24    float64
# OBPM           float64
# DBPM           float64
# BPM            float64
# VORP           float64
# dtype: object

# %%
df.head()
# Out:
#    Rk         Player Pos  Age   Tm   G    MP   PER    TS%   3PAr  ...  \
# 0   1     Quincy Acy  PF   24  NYK  68  1287  11.9  0.533  0.181  ...
# 1   2   Jordan Adams  SG   20  MEM  30   248  12.8  0.489  0.291  ...
# 2   3   Steven Adams   C   21  OKC  70  1771  14.1  0.549  0.005  ...
# 3   4    Jeff Adrien  PF   28  MIN  17   215  14.2  0.494  0.000  ...
# 4   5  Arron Afflalo  SG   29  TOT  78  2502  10.7  0.533  0.377  ...
#
#    Unnamed: 19  OWS  DWS   WS  WS/48  Unnamed: 24  OBPM  DBPM  BPM  VORP
# 0          NaN  1.0  0.7  1.7  0.063          NaN  -2.3  -0.8 -3.1  -0.3
# 1          NaN  0.0  0.4  0.4  0.073          NaN  -1.8   1.2 -0.6   0.1
# 2          NaN  1.9  2.2  4.1  0.111          NaN  -1.4   1.8  0.4   1.1
# 3          NaN  0.2  0.2  0.4  0.087          NaN  -2.7   0.5 -2.2   0.0
# 4          NaN  1.6  1.0  2.6  0.050          NaN  -0.5  -1.3 -1.8   0.1
#
# [5 rows x 29 columns]

# %%
new_survived=pd.Categorical(df['Survived'])
#new_survived=new_survived.rename_categories(["died","Survived"])
#new_survived.describe()
new_survived
# Out:
# [0, 1, 1, 1, 0, ..., 1, 0, 0, 0, 0]
# Length: 156
# Categories (2, int64): [0, 1]

# %%
df.rename
# Out:
# <bound method DataFrame.rename of       Rk                 Player Pos  Age   Tm   G    MP   PER    TS%   3PAr  \
# 0      1             Quincy Acy  PF   24  NYK  68  1287  11.9  0.533  0.181
# 1      2           Jordan Adams  SG   20  MEM  30   248  12.8  0.489  0.291
# 2      3           Steven Adams   C   21  OKC  70  1771  14.1  0.549  0.005
# 3      4            Jeff Adrien  PF   28  MIN  17   215  14.2  0.494  0.000
# 4      5          Arron Afflalo  SG   29  TOT  78  2502  10.7  0.533  0.377
# 5      5          Arron Afflalo  SG   29  DEN  53  1750  11.7  0.533  0.370
# 6      5          Arron Afflalo  SG   29  POR  25   752   8.2  0.533  0.396
# 7      6          Alexis Ajinca   C   26  NOP  68   957  19.9  0.595  0.000
# 8      7         Furkan Aldemir  PF   23  PHI  41   540  12.0  0.517  0.064
# 9      8           Cole Aldrich   C   26  NYK  61   976  18.1  0.513  0.000
# 10     9      LaMarcus Aldridge  PF   29  POR  71  2512  22.8  0.528  0.074
# ...

# %%
new_Pclass=pd.Categorical(df['Pclass'],ordered=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Pclass'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-b930063ec181> in <module>
# ...

# %%
new_Pclass=new_Pclass.rename_categories(['Class1','Class2','Class3'])
new_Pclass.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-0c877e41990b> in <module>
# ----> 1 new_Pclass=new_Pclass.rename_categories(['Class1','Class2','Class3'])
#       2 new_Pclass.describe()
#
# NameError: name 'new_Pclass' is not defined

# %%
df['Pclass']==new_Pclass
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Pclass'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-6206e14c58f0> in <module>
# ----> 1 df['Pclass']==new_Pclass
#       2 df.head()
#
# ...

# %%
df['Cabin'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Cabin'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-a00b3967e4cd> in <module>
# ----> 1 df['Cabin'].unique()
#
# ...

# %%
df.head()
# Out:
#    Rk         Player Pos  Age   Tm   G    MP   PER    TS%   3PAr  ...  \
# 0   1     Quincy Acy  PF   24  NYK  68  1287  11.9  0.533  0.181  ...
# 1   2   Jordan Adams  SG   20  MEM  30   248  12.8  0.489  0.291  ...
# 2   3   Steven Adams   C   21  OKC  70  1771  14.1  0.549  0.005  ...
# 3   4    Jeff Adrien  PF   28  MIN  17   215  14.2  0.494  0.000  ...
# 4   5  Arron Afflalo  SG   29  TOT  78  2502  10.7  0.533  0.377  ...
#
#    Unnamed: 19  OWS  DWS   WS  WS/48  Unnamed: 24  OBPM  DBPM  BPM  VORP
# 0          NaN  1.0  0.7  1.7  0.063          NaN  -2.3  -0.8 -3.1  -0.3
# 1          NaN  0.0  0.4  0.4  0.073          NaN  -1.8   1.2 -0.6   0.1
# 2          NaN  1.9  2.2  4.1  0.111          NaN  -1.4   1.8  0.4   1.1
# 3          NaN  0.2  0.2  0.4  0.087          NaN  -2.7   0.5 -2.2   0.0
# 4          NaN  1.6  1.0  2.6  0.050          NaN  -0.5  -1.3 -1.8   0.1
#
# [5 rows x 29 columns]

# %%
import numpy as np
char_cabin=df['Cabin'].astype(str)
new_Cabin=np.array([cabin[0] for cabin in char_cabin])
new_Cabin=pd.Categorical(new_Cabin)
new_Cabin.describe()
# Out:
#             counts     freqs
# categories
# A                2  0.012821
# B                5  0.032051
# C               10  0.064103
# D                6  0.038462
# E                3  0.019231
# F                4  0.025641
# G                1  0.006410
# n              125  0.801282

# %%
df['Cabin']=new_Cabin

# %%
df['Cabin']
# Out:
# 0      n
# 1      C
# 2      n
# 3      C
# 4      n
# 5      n
# 6      E
# 7      n
# 8      n
# 9      n
# 10     G
# 11     C
# 12     n
# 13     n
# 14     n
# 15     n
# 16     n
# 17     n
# 18     n
# 19     n
# 20     n
# 21     D
# 22     n
# 23     A
# 24     n
# 25     n
# 26     n
# 27     C
# 28     n
# 29     n
#       ..
# 126    n
# 127    n
# 128    F
# 129    n
# 130    n
# 131    n
# 132    n
# 133    n
# 134    n
# 135    n
# 136    D
# 137    C
# 138    n
# 139    B
# 140    n
# 141    n
# 142    n
# 143    n
# 144    n
# 145    n
# 146    n
# 147    n
# 148    F
# 149    n
# 150    n
# 151    C
# 152    n
# 153    n
# 154    n
# 155    n
# Name: Cabin, Length: 156, dtype: category
# Categories (8, object): [A, B, C, D, E, F, G, n]

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
dummy_Vector=pd.Series()

# %%
type(dummy_Vector)
# Out:
# pandas.core.series.Series

# %%
df=pd.DataFrame()

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
dummy_Vector=pd.Series([1,None,3,None,7,8])
dummy_Vector.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# dtype: bool

# %%
missing=np.where(df['Age'].isnull()==True)

# %%
missing
# Out:
# (array([], dtype=int64),)

# %%
import numpy as np
index=np.where(df['Fare']==max(df['Fare']))
df.loc[index]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-07389dc40b5a> in <module>
#       1 import numpy as np
# ----> 2 index=np.where(df['Fare']==max(df['Fare']))
#       3 df.loc[index]
#
# NameError: name 'df' is not defined
