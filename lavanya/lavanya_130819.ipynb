# %%
import pandas as pd
import numpy as np

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\LAVANYA\\Desktop\\datascience'

# %%
df=pd.read_csv('new_sale.csv')

# %%
df

# %%
df=df.rename(columns={'Quantity':'Customer Growth'})

# %%
df.head()
# Out:
#       Retailer country Order method type  Retailer type  \
# 0        United States               Fax  Outdoors Shop
# 1        United States               Fax  Outdoors Shop
# 2        United States               Fax  Outdoors Shop
# 3        United States               Fax  Outdoors Shop
# 4        United States               Fax  Outdoors Shop
# 8617     United States               Fax  Outdoors Shop
# 8618     United States               Fax  Outdoors Shop
# 8619     United States               Fax  Outdoors Shop
# 8620     United States               Fax  Outdoors Shop
# 8621     United States               Fax  Outdoors Shop
# 17419    United States               Fax  Outdoors Shop
# 17420    United States               Fax  Outdoors Shop
# 17421    United States               Fax  Outdoors Shop
# 17422    United States               Fax  Outdoors Shop
# 17423    United States               Fax  Outdoors Shop
# 25967    United States               Fax  Outdoors Shop
# ...

# %% [markdown]
# # Quarterly customer growth trend

# %%
df.sort_values(by='Quarter')
# Out:
#       Retailer country Order method type     Retailer type  \
# 0        United States               Fax     Outdoors Shop
# 5752            France       Sales visit  Department Store
# 5751            France       Sales visit  Department Store
# 5750            France       Sales visit  Department Store
# 5749            France       Sales visit  Department Store
# 5748            France       Sales visit  Department Store
# 5747            France       Sales visit  Department Store
# 5746            France       Sales visit  Department Store
# 5745            France       Sales visit  Department Store
# 5744            France       Sales visit  Department Store
# 5743            France       Sales visit  Department Store
# 5742            France               Web      Sports Store
# 5741            France               Web      Sports Store
# 5740            France               Web      Sports Store
# 5739            France               Web      Sports Store
# ...

# %%
df=df.groupby('Quarter')

# %%
df
